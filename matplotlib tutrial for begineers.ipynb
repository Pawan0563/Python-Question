# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\pawan kumar singh\anaconda3\lib\site-packages (3.5.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\pawan kumar singh\anaconda3\lib\site-packages (from matplotlib) (1.20.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\pawan kumar singh\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\pawan kumar singh\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pawan kumar singh\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\pawan kumar singh\anaconda3\lib\site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\pawan kumar singh\anaconda3\lib\site-packages (from matplotlib) (21.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pawan kumar singh\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\pawan kumar singh\anaconda3\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: six in c:\users\pawan kumar singh\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib) (1.16.0)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Interactive Graphics

# %%
data = np.arange(10)

# %%
# %matplotlib notebook

# %%
plt.plot(data)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.title("interactive test")
# Out:
# Text(0.5, 1.0, 'interactive test')

# %%
plt.ylabel("sample value")
# Out:
# Text(0, 0.5, 'sample value')

# %% [markdown]
# Static Graphics

# %%
# %matplotlib inline

# %%
x=[1,2,3,4]
y=[1,4,9,16]

plt.plot(x,y)

# %%
d=np.arange(0.,5.,0.2)

# %%
plt.plot(d, d,'r--',d,d**2,'bs',d,d**3,'g^')
# Out:
# [<matplotlib.lines.Line2D at 0x1c590dd1760>,
#  <matplotlib.lines.Line2D at 0x1c590dd1730>,
#  <matplotlib.lines.Line2D at 0x1c590dd1910>]

# %% [markdown]
# Save the Graph

# %%
plt.savefig('my-graph.png')

# %%
plt.savefig('my-graph-2.png',
            dpi=400, bbox_inches='tight')

# %% [markdown]
# Matplotlib Tutorial for Beginners

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib notebook

# %%
fig=plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax1 = fig.add_subplot(2, 2, 1)

# %%
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

# %%
data=np.random.randn(50,).cumsum()

# %%
ax1.plot(data, 'k--')

# %%
ax2.plot(data, "r-")
ax3.plot(data, "b.")

# %% [markdown]
# Color, Markings, and Line Styles

# %%
x=[1,2,3,4,5]
y=[10,11,12,13,14]

# %%
fig=plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax.plot(x, y, 'r--')

# %%
ax.plot(x, y, linestyle='--', color='r')

# %%
plt.plot?

# %%
plt.plot(data, 'ko--')

# %%
# %matplotlib inline

# %%
plt.plot(data, 'k--', label='Default')

# %%
plt.plot(data, 
         'k-', 
         drawstyle='steps-post', 
         label='Stepwise')

# %%
plt.plot(data, 'k-', 
         drawstyle='steps-post', 
         label='Stepwise')
plt.legend(loc='best')

# %% [markdown]
# Thickness, Label and Legend

# %%
# %matplotlib notebook

# %%
fig=plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax = fig.add_subplot(1, 1, 1)

# %%
ax.plot(data)

# %%
location=ax.set_xticks([0,10,20,30,40,50])
label=ax.set_xticklabels(
    ["one","two","three","four","five","six"],
    rotation=30,
    fontsize="small")

# %%
ax.set_title('First Graph')
# Out:
# Text(0.5, 1.0, 'First Graph')

# %%
ax.set_xlabel('Stages')
ax.set_ylabel('Anything')
# Out:
# Text(0, 0.5, 'Anything')

# %%
feature={"title":"Perfect Graph", 
         "xlabel":"Steps", 
         "ylabel":"Numbers"}

# %%
ax.set(**feature)
# Out:
# [Text(0.5, 1.0, 'Perfect Graph'),
#  Text(0.5, 0, 'Steps'),
#  Text(0, 0.5, 'Numbers')]

# %% [markdown]
# Adding Legends

# %%
fig=plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax=fig.add_subplot(1,1,1)

# %%
data1=np.random.randn(1000).cumsum()
data2=np.random.randn(1000).cumsum()
data3=np.random.randn(1000).cumsum()

# %%
ax.plot(data1, 'k', label='one')
ax.plot(data2, 'b--', label='two')
ax.plot(data3, 'r.', label='three')

# %%
ax.legend()

# %% [markdown]
# Annotations and Drawing on a Subplot

# %%
import pandas as pd

# %%
df = pd.read_csv('FB.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  30-07-2018  175.300003  175.300003  166.559998  171.059998  171.059998
# 1  31-07-2018  170.669998  174.240005  170.000000  172.580002  172.580002
# 2  01-08-2018  173.929993  175.080002  170.899994  171.649994  171.649994
# 3  02-08-2018  170.679993  176.789993  170.270004  176.369995  176.369995
# 4  03-08-2018  177.690002  178.850006  176.149994  177.779999  177.779999
#
#      Volume
# 0  65280800
# 1  40356500
# 2  34042100
# 3  32400000
# 4  24763400

# %%
df=pd.read_csv('FB.csv', 
               index_col=0, 
               parse_dates=True)

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-07-30  175.300003  175.300003  166.559998  171.059998  171.059998
# 2018-07-31  170.669998  174.240005  170.000000  172.580002  172.580002
# 2018-01-08  173.929993  175.080002  170.899994  171.649994  171.649994
# 2018-02-08  170.679993  176.789993  170.270004  176.369995  176.369995
# 2018-03-08  177.690002  178.850006  176.149994  177.779999  177.779999
#
#               Volume
# Date
# 2018-07-30  65280800
# 2018-07-31  40356500
# 2018-01-08  34042100
# 2018-02-08  32400000
# 2018-03-08  24763400

# %%
c_price=df["Close"]

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
c_price.plot(ax=ax, style='k-')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
ax.set_title(
    'Facebook stock closing prices')
# Out:
# Text(0.5, 1.0, 'Facebook stock closing prices')

# %%
c_price.min()
# Out:
# 124.059998

# %%
c_price["2018-12-24"]
# Out:
# Date
# 2018-12-24    124.059998
# Name: Close, dtype: float64

# %%
date="2018-12-24"
text="Minimum"

# %%
ax.annotate(
    text, xy=(date,125), xytext=(date,150), 
    arrowprops=dict(facecolor='red'))
# Out:
# Text(2018-12-24, 150, 'Minimum')

# %% [markdown]
# Saving Plots to File

# %%
plt.savefig("my-graph.pdf")

# %%
plt.savefig("my-graph.png")

# %%
plt.savefig("my-graph.png", dpi=500)

# %%
plt.savefig("my-graph.png", 
            dpi=500, 
            bbox_inches="tight")
